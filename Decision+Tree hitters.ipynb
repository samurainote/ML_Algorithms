# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
from sklearn.tree import DecisionTreeRegressor as dtr
from sklearn import tree
from sklearn.model_selection import GridSearchCV, train_test_split

# %%
df = pd.read_csv("Downloads/Byte academy my data/Decision tree/Hitters.csv")

# %%
df.describe()
df1 = df.drop(["League","NewLeague","Errors","AtBat","Unnamed: 0","HmRun","CAtBat","CHits","Division","CRuns","CHmRun","CRBI","CWalks"],axis=1)

# %%
df1["Salary"].fillna(df["Salary"].mean(), inplace=True)

# %%
df1
# Out:
#      Hits  Runs  RBI  Walks  Years  PutOuts  Assists       Salary
# 0      66    30   29     14      1      446       33   535.925882
# 1      81    24   38     39     14      632       43   475.000000
# 2     130    66   72     76      3      880       82   480.000000
# 3     141    65   78     37     11      200       11   500.000000
# 4      87    39   42     30      2      805       40    91.500000
# 5     169    74   51     35     11      282      421   750.000000
# 6      37    23    8     21      2       76      127    70.000000
# 7      73    24   24      7      3      121      283   100.000000
# 8      81    26   32      8      2      143      290    75.000000
# 9      92    49   66     65     13        0        0  1100.000000
# 10    159   107   75     59     10      238      445   517.143000
# 11     53    31   26     27      9      304       45   512.500000
# 12    113    48   61     47      4      211       11   550.000000
# 13     60    30   11     22      6      121      151   700.000000
# 14     43    29   27     30     13       80       45   240.000000
# 15     39    20   15     11      3      118        0   535.925882
# 16    158    89   75     73     15      105      290   775.000000
# 17     46    24    8     15      5      102      177   175.000000
# 18    104    57   43     65     12      912       88   535.925882
# 19     32    16   22     14      8      202       22   135.000000
# 20     92    72   48     65      1      280        9   100.000000
# 21    109    55   43     62      1      361       22   115.000000
# 22     10     4    2      1      6      812       84   535.925882
# 23    116    60   62     74      6      518       55   600.000000
# 24    168    73  102     40     18     1067      157   776.667000
# 25    163    92   51     70      6      434        9   765.000000
# 26     73    32   18     22      7      222        3   708.333000
# 27    129    50   56     40     10      732       83   750.000000
# 28    152    92   37     81      5      262      329   625.000000
# 29    137    90   95     90     14      267        5   900.000000
# ..    ...   ...  ...    ...    ...      ...      ...          ...
# 292    63    36   41     44     17      166      211   535.925882
# 293   141    48   61     73      8      352      414   925.000000
# 294   120    53   44     21      4       70      144   185.000000
# 295     4     2    3      1      1      692       70   920.000000
# 296    43    24   17     20      7      131        6   286.667000
# 297    47    21   29     24      6      299       13   245.000000
# 298    46    19   18     17      5       37       98   535.925882
# 299    61    17   22      3     17      178       45   235.000000
# 300   147    56   52     53      7      810       99  1150.000000
# 301   138    56   59     34      3      133      371   160.000000
# 302    51    14   29     25     23      398       29   535.925882
# 303   113    76   52     76      5      160      290   425.000000
# 304    42    17   14     15     10       65        0   900.000000
# 305   194    91   62     78      8      270       13   535.925882
# 306    32    14   25     12     19      167       18   500.000000
# 307    69    35   31     32      4      133      173   277.500000
# 308   112    50   71     44      7       94      270   750.000000
# 309   139    94   29     60      2      300       12   160.000000
# 310   186   107   98     74      6     1182       96  1300.000000
# 311    81    37   44     37      7      170      284   525.000000
# 312   124    67   27     36      7      186      290   550.000000
# 313   207   107   71    105      5      121      267  1600.000000
# 314   117    66   41     34      1      942       72   120.000000
# 315   172    82  100     57      1     1222      139   165.000000
# 316    53    21   23     22      8      325       58   535.925882
# 317   127    65   48     37      5      325        9   700.000000
# 318   136    76   50     94     12      313      381   875.000000
# 319   126    61   43     52      6       37      113   385.000000
# 320   144    85   60     78      8     1314      131   960.000000
# 321   170    77   44     31     11      408        4  1000.000000
#
# [322 rows x 8 columns]

# %%
df1["Salary"] = df1["Salary"].apply(np.log) 
y = df1["Salary"]
df1 = df1.drop("Salary",axis=1)
df1
# Out:
#      Hits  Runs  RBI  Walks  Years  PutOuts  Assists
# 0      66    30   29     14      1      446       33
# 1      81    24   38     39     14      632       43
# 2     130    66   72     76      3      880       82
# 3     141    65   78     37     11      200       11
# 4      87    39   42     30      2      805       40
# 5     169    74   51     35     11      282      421
# 6      37    23    8     21      2       76      127
# 7      73    24   24      7      3      121      283
# 8      81    26   32      8      2      143      290
# 9      92    49   66     65     13        0        0
# 10    159   107   75     59     10      238      445
# 11     53    31   26     27      9      304       45
# 12    113    48   61     47      4      211       11
# 13     60    30   11     22      6      121      151
# 14     43    29   27     30     13       80       45
# 15     39    20   15     11      3      118        0
# 16    158    89   75     73     15      105      290
# 17     46    24    8     15      5      102      177
# 18    104    57   43     65     12      912       88
# 19     32    16   22     14      8      202       22
# 20     92    72   48     65      1      280        9
# 21    109    55   43     62      1      361       22
# 22     10     4    2      1      6      812       84
# 23    116    60   62     74      6      518       55
# 24    168    73  102     40     18     1067      157
# 25    163    92   51     70      6      434        9
# 26     73    32   18     22      7      222        3
# 27    129    50   56     40     10      732       83
# 28    152    92   37     81      5      262      329
# 29    137    90   95     90     14      267        5
# ..    ...   ...  ...    ...    ...      ...      ...
# 292    63    36   41     44     17      166      211
# 293   141    48   61     73      8      352      414
# 294   120    53   44     21      4       70      144
# 295     4     2    3      1      1      692       70
# 296    43    24   17     20      7      131        6
# 297    47    21   29     24      6      299       13
# 298    46    19   18     17      5       37       98
# 299    61    17   22      3     17      178       45
# 300   147    56   52     53      7      810       99
# 301   138    56   59     34      3      133      371
# 302    51    14   29     25     23      398       29
# 303   113    76   52     76      5      160      290
# 304    42    17   14     15     10       65        0
# 305   194    91   62     78      8      270       13
# 306    32    14   25     12     19      167       18
# 307    69    35   31     32      4      133      173
# 308   112    50   71     44      7       94      270
# 309   139    94   29     60      2      300       12
# 310   186   107   98     74      6     1182       96
# 311    81    37   44     37      7      170      284
# 312   124    67   27     36      7      186      290
# 313   207   107   71    105      5      121      267
# 314   117    66   41     34      1      942       72
# 315   172    82  100     57      1     1222      139
# 316    53    21   23     22      8      325       58
# 317   127    65   48     37      5      325        9
# 318   136    76   50     94     12      313      381
# 319   126    61   43     52      6       37      113
# 320   144    85   60     78      8     1314      131
# 321   170    77   44     31     11      408        4
#
# [322 rows x 7 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(df1,y,test_size = 0.2)

# %%
regressor = dtr(random_state=0)

# %%
y_pred = regressor.fit(x_train,y_train)
y_pred
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=0, splitter='best')

# %%
# out_file is the filename this .dot file will be saved in this folder
# at the terminal, cd into this folder and dot -Tpng hitter_tree1.dot -o hitter_tree1.png  
tree.export_graphviz(regressor,out_file='hitter_tree1.dot')

# %%
predictions = y_pred.predict(x_test)
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(y_test, predictions))
print("RMSE for training data:", rmse)
# Out:
# RMSE for training data: 0.8047252761834176

# %%
parameters = {
     'max_features':(None, 4, 6,7), # numbers of features per tree to try
     'max_depth':(None, 8, 16),
     'min_samples_split': (2, 4, 8),
     'min_samples_leaf': (4,6,8,12)
}

# %%
clf = GridSearchCV(regressor, parameters, cv=5, n_jobs=4)
clf.fit(x_train, y_train)
print("==============================================")
clf.score(x_test, y_test)
# Out:
# ==============================================
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# 0.365235057492483

# %%
clf.best_score_
# Out:
# 0.34792976251166624
